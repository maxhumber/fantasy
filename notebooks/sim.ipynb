# %%
import pandas as pd
import numpy as np
import random
from collections import Counter

pd.options.display.max_rows = 1_000

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("../data/draft-250.csv")
df = df.sort_values("pick")
df["position"] = np.where(df["position_yahoo"].isin(["G", "D"]), df["position_yahoo"], "F")
df.head()
# Out:
#   team   age              name position_yahoo  rollup  vorp  vorn  round  \
# 2  Edm  23.0    Connor McDavid              C    70.2  14.7   7.6    1.0
# 0  Col  25.0  Nathan MacKinnon              C    73.6  18.1  11.0    1.0
# 5  Edm  25.0    Leon Draisaitl           C,LW    67.0  12.9   7.2    1.0
# 9  NYR  29.0    Artemi Panarin             LW    63.3   9.2   3.5    1.0
# 3  Was  35.0     Alex Ovechkin             LW    68.5  14.4   8.7    1.0
#
#    pick  rank  arbitrage  target position
# 2   1.0   3.0       -2.0    True        F
# 0   2.0   1.0        1.0    True        F
# 5   3.0   6.0       -3.0    True        F
# 9   4.0  10.0       -6.0    True        F
# 3   5.0   4.0        1.0   False        F

# %% [markdown]
# ### Player Class

# %%
class Player:
    
    def __init__(self, name, position, yahoo, vorp):
        self.name = name
        self.position = position
        self.yahoo = yahoo
        self.vorp = vorp 
        
    def __repr__(self):
        return f'Player("{self.name}", "{self.position}", {self.yahoo}, {self.vorp})'

# %% [markdown]
# ### Data

# %%
players = []
for i, row in df.iterrows():
    player = Player(row["name"], row.position, row.pick, row.vorp)
    players.append(player)
    
players[:5]
# Out:
# [Player("Connor McDavid", "F", 1.0, 14.7),
#  Player("Nathan MacKinnon", "F", 2.0, 18.1),
#  Player("Leon Draisaitl", "F", 3.0, 12.9),
#  Player("Artemi Panarin", "F", 4.0, 9.2),
#  Player("Alex Ovechkin", "F", 5.0, 14.4)]

# %% [markdown]
# ### Pool Settings

# %%
TEAMS = 12
SLOTS = {'F': 6, 'D': 4, 'G': 2}
BENCH = 4
PICKS = (sum(SLOTS.values()) + BENCH) * TEAMS

# %% [markdown]
# ### Team Class

# %%
class Team:
    
    def __init__(self, order, pick_strategy):
        self.players = []
        self.order = order
        self.pick_strategy = pick_strategy
        
    def __repr__(self): 
        return f"Team({self.order})"

    def pick(self, available):
        player = self.pick_strategy(available, self.players)
        self.players.append(player)
        available.remove(player)
        return player

# %% [markdown]
# ### Strategies

# %%
def strategy_1(available, current_team):
    """Draft top position still required"""
    slots_to_fill = Counter(SLOTS)

    # if there are players in currently on the team, subtract those positions
    if current_team:
        slots_to_fill -= Counter([player.position for player in current_team])
        
    # if there are no more slots to fill
    if not slots_to_fill: 
        
        # return top ranked pick
        return available[0]
    
    # otherwise loop
    for player in available:
        
        # if slot still required
        if slots_to_fill.get(player.position, 0) > 0: 
            
            # pick player
            return player

def strategy_2(available, current_team):
    "Draft top Yahoo ranked picked, no matter what"
    return available[0]

def strategy_3(available, current_team):
    """Draft randomly"""
    return random.choice(available)

# %%
def strategy_0(available, current_team):
    """Draft VORP"""
    slots_to_fill = Counter(SLOTS)

    # if there are players in currently on the team, subtract those positions
    if current_team:
        slots_to_fill -= Counter([player.position for player in current_team])
        
    # rank
    ranked = sorted(available, key=lambda x: x.vorp, reverse=True)
        
    # if there are no more slots to fill
    if not slots_to_fill: 
        
        # return top ranked pick
        return ranked[0]
    
    # otherwise loop
    for player in ranked:
        
        # if slot still required
        if slots_to_fill.get(player.position, 0) > 0: 
            
            # pick player
            return player

# %% [markdown]
# ### Simulate

# %%
def snake(low, high, x):
    k = (high - low + 1)
    return k - int(abs(x % (2*k) + low - k - 0.5))

draft_order = [snake(1, 12, x) for x in range(PICKS)]

# %%
teams = {order: Team(order, strategy_1) for order in range(1, TEAMS+1)}

# %%
# pick 
teams[11] = Team(11, strategy_0)

# %%
available = players.copy()
for i, team in enumerate(draft_order):
    print(i+1, team, teams[team].pick(available))
# Out:
# 1 1 Player("Connor McDavid", "F", 1.0, 14.7)
# 2 2 Player("Nathan MacKinnon", "F", 2.0, 18.1)
# 3 3 Player("Leon Draisaitl", "F", 3.0, 12.9)
# 4 4 Player("Artemi Panarin", "F", 4.0, 9.2)
# 5 5 Player("Alex Ovechkin", "F", 5.0, 14.4)
# 6 6 Player("Auston Matthews", "F", 6.0, 8.2)
# 7 7 Player("Andrei Vasilevskiy", "G", 7.0, 16.4)
# 8 8 Player("Jack Eichel", "F", 8.0, 3.3)
# 9 9 Player("Nikita Kucherov", "F", 9.0, 3.7)
# 10 10 Player("Patrick Kane", "F", 10.0, 7.3)
# 11 11 Player("Roman Josi", "D", 29.0, 13.2)
# 12 12 Player("Victor Hedman", "D", 14.0, 12.5)
# 13 12 Player("John Carlson", "D", 21.0, 12.3)
# 14 11 Player("Dougie Hamilton", "D", 46.5, 11.3)
# 15 10 Player("Sebastian Aho", "F", 11.0, 1.6)
# 16 9 Player("Sidney Crosby", "F", 12.0, 4.2)
# 17 8 Player("Mikko Rantanen", "F", 13.0, 6.0)
# 18 7 Player("Elias Pettersson", "F", 15.0, -1.7)
# 19 6 Player("Andrei Svechnikov", "F", 16.0, 3.8)
# 20 5 Player("Connor Hellebuyck", "G", 17.0, 5.6)
# 21 4 Player("Mika Zibanejad", "F", 18.5, 7.1)
# 22 3 Player("Mitchell Marner", "F", 18.5, 3.2)
# 23 2 Player("Brayden Point", "F", 20.0, -2.9)
# 24 1 Player("Brad Marchand", "F", 22.0, 5.6)
# 25 1 Player("Steven Stamkos", "F", 23.0, 6.7)
# 26 2 Player("Jonathan Huberdeau", "F", 24.5, -3.9)
# 27 3 Player("Jake Guentzel", "F", 24.5, 2.4)
# 28 4 Player("Patrik Laine", "F", 26.0, 0.2)
# 29 5 Player("Evgeni Malkin", "F", 27.0, 3.6)
# 30 6 Player("John Tavares", "F", 28.0, -1.0)
# 31 7 Player("Matthew Tkachuk", "F", 30.5, 2.1)
# 32 8 Player("Tuukka Rask", "G", 30.5, 5.3)
# 33 9 Player("Cale Makar", "D", 32.0, 6.9)
# 34 10 Player("Carter Hart", "G", 33.0, 3.8)
# 35 11 Player("Philipp Grubauer", "G", 72.0, 8.2)
# 36 12 Player("Brent Burns", "D", 54.0, 6.0)
# 37 12 Player("Neal Pionk", "D", 80.5, 5.9)
# 38 11 Player("Igor Shesterkin", "G", 51.0, 5.6)
# 39 10 Player("Robin Lehner", "G", 34.0, 2.6)
# 40 9 Player("Gabriel Landeskog", "F", 35.0, -0.1)
# 41 8 Player("Blake Wheeler", "F", 36.0, 1.9)
# 42 7 Player("Mark Stone", "F", 37.0, 1.4)
# 43 6 Player("Max Pacioretty", "F", 38.0, 5.3)
# 44 5 Player("Aleksander Barkov", "F", 39.0, -7.1)
# 45 4 Player("Jordan Binnington", "G", 40.0, 0.4)
# 46 3 Player("Patrice Bergeron", "F", 41.5, -1.2)
# 47 2 Player("J.T. Miller", "F", 41.5, 3.4)
# 48 1 Player("Mark Scheifele", "F", 43.5, -7.3)
# 49 1 Player("Teuvo Teravainen", "F", 43.5, -1.8)
# 50 2 Player("Ilya Samsonov", "G", 45.0, -4.6)
# 51 3 Player("David Pastrnak", "F", 46.5, 3.6)
# 52 4 Player("Johnny Gaudreau", "F", 48.0, -2.0)
# 53 5 Player("Carey Price", "G", 49.0, -3.7)
# 54 6 Player("Brady Tkachuk", "F", 50.0, -0.2)
# 55 7 Player("Frederik Andersen", "G", 52.0, 4.4)
# 56 8 Player("Taylor Hall", "F", 53.0, -5.3)
# 57 9 Player("Alex Pietrangelo", "D", 55.0, 4.9)
# 58 10 Player("Ryan O'Reilly", "F", 56.0, -8.5)
# 59 11 Player("Kris Letang", "D", 66.0, 5.3)
# 60 12 Player("Torey Krug", "D", 67.0, 4.6)
# 61 12 Player("Shea Theodore", "D", 91.0, 2.9)
# 62 11 Player("Morgan Rielly", "D", 58.0, 2.2)
# 63 10 Player("Evgeny Kuznetsov", "F", 58.0, -10.8)
# 64 9 Player("Quinn Hughes", "D", 58.0, -2.4)
# 65 8 Player("Sean Couturier", "F", 60.0, -6.9)
# 66 7 Player("Tristan Jarry", "G", 61.0, -6.4)
# 67 6 Player("Claude Giroux", "F", 62.0, -6.3)
# 68 5 Player("Darcy Kuemper", "G", 63.0, -2.5)
# 69 4 Player("Kyle Connor", "F", 64.0, -6.0)
# 70 3 Player("Elias Lindholm", "F", 65.0, -3.6)
# 71 2 Player("Filip Forsberg", "F", 68.0, -6.2)
# 72 1 Player("Brendan Gallagher", "F", 69.0, -4.8)
# 73 1 Player("Ryan Nugent-Hopkins", "F", 70.0, -5.7)
# 74 2 Player("Miro Heiskanen", "D", 71.0, 0.3)
# 75 3 Player("Brock Boeser", "F", 73.0, -9.9)
# 76 4 Player("Anton Khudobin", "G", 74.0, 1.2)
# 77 5 Player("Evander Kane", "F", 75.0, -4.7)
# 78 6 Player("Zach Werenski", "D", 76.0, 1.0)
# 79 7 Player("Brayden Schenn", "F", 77.0, -3.8)
# 80 8 Player("Jacob Markstrom", "G", 78.0, -3.6)
# 81 9 Player("Marc-Andre Fleury", "G", 79.0, -19.1)
# 82 10 Player("Seth Jones", "D", 80.5, -1.1)
# 83 11 Player("Jonathan Marchessault", "F", 97.0, -2.7)
# 84 12 Player("Shea Weber", "D", 92.0, 1.7)
# 85 12 Player("Tony DeAngelo", "D", 102.0, 1.3)
# 86 11 Player("Mike Hoffman", "F", 86.0, -3.5)
# 87 10 Player("William Nylander", "F", 82.0, -6.8)
# 88 9 Player("Erik Karlsson", "D", 83.0, -1.4)
# 89 8 Player("Mathew Barzal", "F", 84.5, -11.1)
# 90 7 Player("Travis Konecny", "F", 84.5, -6.9)
# 91 6 Player("Rasmus Dahlin", "D", 87.0, -1.9)
# 92 5 Player("Timo Meier", "F", 88.0, -7.4)
# 93 4 Player("Petr Mrazek", "G", 89.0, -4.2)
# 94 3 Player("Tom Wilson", "F", 90.0, -5.4)
# 95 2 Player("Pierre-Luc Dubois", "F", 93.0, -10.3)
# 96 1 Player("Ivan Provorov", "D", 94.0, -1.8)
# 97 1 Player("Pavel Francouz", "G", 95.5, -15.3)
# 98 2 Player("Alex DeBrincat", "F", 95.5, -8.6)
# 99 3 Player("John Klingberg", "D", 98.0, -3.6)
# 100 4 Player("Kevin Fiala", "F", 99.0, -8.3)
# 101 5 Player("Tyson Barrie", "D", 100.0, -2.7)
# 102 6 Player("Braden Holtby", "G", 101.0, 0.6)
# 103 7 Player("Kailer Yamamoto", "F", 103.0, -7.2)
# 104 8 Player("Anders Lee", "F", 104.0, -7.2)
# 105 9 Player("Jeff Petry", "D", 105.0, 0.1)
# 106 10 Player("Jakub Vrana", "F", 106.0, -14.2)
# 107 11 Player("David Perron", "F", 124.0, -4.8)
# 108 12 Player("Ryan Ellis", "D", 121.0, 0.5)
# 109 12 Player("Ryan Pulock", "D", 120.0, 0.4)
# 110 11 Player("Patric Hornqvist", "F", 151.0, -5.0)
# 111 10 Player("Charlie McAvoy", "D", 107.0, -1.8)
# 112 9 Player("Elvis Merzlikins", "G", 108.0, -11.9)
# 113 8 Player("Kyle Palmieri", "F", 109.0, -7.2)
# 114 7 Player("Thomas Chabot", "D", 110.0, -2.7)
# 115 6 Player("Oliver Ekman-Larsson", "D", 111.0, -3.6)
# 116 5 Player("Nicklas Backstrom", "F", 112.0, -11.1)
# 117 4 Player("Logan Couture", "F", 113.0, -13.7)
# 118 3 Player("Adam Fox", "D", 114.0, -1.6)
# 119 2 Player("Jamie Benn", "F", 115.0, -7.4)
# 120 1 Player("Mark Giordano", "D", 116.0, -0.5)
# 121 1 Player("Juuse Saros", "G", 117.0, -1.2)
# 122 2 Player("Ben Bishop", "G", 118.0, -18.2)
# 123 3 Player("Alexander Radulov", "F", 119.0, -8.6)
# 124 4 Player("Keith Yandle", "D", 122.0, -4.1)
# 125 5 Player("Jaroslav Halak", "G", 123.0, -10.4)
# 126 6 Player("Joonas Korpisalo", "G", 125.0, -3.6)
# 127 7 Player("Mikhail Sergachev", "D", 126.0, -1.5)
# 128 8 Player("Sam Reinhart", "F", 127.0, -15.2)
# 129 9 Player("Dominik Kubalik", "F", 128.0, -8.5)
# 130 10 Player("Rasmus Ristolainen", "D", 129.0, -1.7)
# 131 11 Player("Bryan Rust", "F", 178.0, -4.6)
# 132 12 Player("Darnell Nurse", "D", 142.0, -1.1)
# 133 12 Player("Drew Doughty", "D", 136.5, -1.3)
# 134 11 Player("Chris Kreider", "F", 136.5, -5.9)
# 135 10 Player("Sergei Bobrovsky", "G", 130.0, -4.8)
# 136 9 Player("Dylan Larkin", "F", 131.0, -13.8)
# 137 8 Player("Victor Olofsson", "F", 132.0, -11.3)
# 138 7 Player("Aaron Ekblad", "D", 133.0, -4.2)
# 139 6 Player("Alexis Lafreniere", "F", 134.0, -47.2)
# 140 5 Player("Colton Parayko", "D", 135.0, -2.2)
# 141 4 Player("Ryan Strome", "F", 138.0, -6.4)
# 142 3 Player("Tomas Hertl", "F", 139.0, -15.6)
# 143 2 Player("Anze Kopitar", "F", 140.5, -11.5)
# 144 1 Player("Jacob Trouba", "D", 140.5, -2.5)
# 145 1 Player("Ryan Suter", "D", 143.0, -4.6)
# 146 2 Player("Nazem Kadri", "F", 144.0, -9.3)
# 147 3 Player("Sean Monahan", "F", 145.0, -11.0)
# 148 4 Player("Matt Dumba", "D", 146.0, -7.2)
# 149 5 Player("Bo Horvat", "F", 147.0, -14.2)
# 150 6 Player("Kirill Kaprizov", "F", 148.5, -14.9)
# 151 7 Player("Jonathan Toews", "F", 148.5, -20.5)
# 152 8 Player("Ryan Graves", "D", 150.0, -4.5)
# 153 9 Player("Nate Schmidt", "D", 152.0, -10.4)
# 154 10 Player("T.J. Oshie", "F", 153.5, -10.3)
# 155 11 Player("Semyon Varlamov", "G", 163.0, -3.1)
# 156 12 Player("Jake Muzzin", "D", 164.0, -3.6)
# 157 12 Player("Alexander Edler", "D", 261.0, -3.8)
# 158 11 Player("Cam Talbot", "G", 217.0, -4.4)
# 159 10 Player("Reilly Smith", "F", 153.5, -6.7)
# 160 9 Player("Matt Duchene", "F", 155.0, -16.5)
# 161 8 Player("Blake Coleman", "F", 156.0, -6.5)
# 162 7 Player("Jaden Schwartz", "F", 157.0, -10.8)
# 163 6 Player("Jaccob Slavin", "D", 158.5, -7.8)
# 164 5 Player("Tomas Tatar", "F", 158.5, -6.9)
# 165 4 Player("Jack Hughes", "F", 160.0, -23.7)
# 166 3 Player("John Gibson", "G", 161.0, -9.9)
# 167 2 Player("Nico Hischier", "F", 162.0, -17.7)
# 168 1 Player("Viktor Arvidsson", "F", 166.0, -8.7)
# 169 1 Player("Thatcher Demko", "G", 166.0, -15.6)
# 170 2 Player("Zdeno Chara", "D", 166.0, nan)
# 171 3 Player("Cam Atkinson", "F", 168.0, -9.1)
# 172 4 Player("Kirby Dach", "F", 169.0, -45.9)
# 173 5 Player("Nikolaj Ehlers", "F", 170.0, -10.7)
# 174 6 Player("Kevin Shattenkirk", "D", 171.0, -7.3)
# 175 7 Player("Quinton Byfield", "F", 172.0, -48.6)
# 176 8 Player("Anthony Mantha", "F", 173.0, -12.3)
# 177 9 Player("Vladimir Tarasenko", "F", 174.0, -14.2)
# 178 10 Player("Jonathan Quick", "G", 176.0, -12.1)
# 179 11 Player("Jared Spurgeon", "D", 181.0, -6.0)
# 180 12 Player("Erik Cernak", "D", 182.0, -6.7)
# 181 12 Player("P.K. Subban", "D", 214.5, -8.4)
# 182 11 Player("Samuel Girard", "D", 231.0, -8.9)
# 183 10 Player("Max Domi", "F", 176.0, -15.8)
# 184 9 Player("Ondrej Palat", "F", 176.0, -10.7)
# 185 8 Player("Tyler Seguin", "F", 179.0, -16.8)
# 186 7 Player("Pekka Rinne", "G", 180.0, -15.5)
# 187 6 Player("Joe Pavelski", "F", 183.5, -12.5)
# 188 5 Player("Craig Smith", "F", 183.5, -11.3)
# 189 4 Player("Ryan Reaves", "F", 185.5, -19.5)
# 190 3 Player("Linus Ullmark", "G", 185.5, -10.5)
# 191 2 Player("Malcolm Subban", "G", 187.0, -13.7)
# 192 1 Player("Kaapo Kakko", "F", 188.0, -21.6)

# %%
data = []
for team in teams:
    players_on_team = [p.name for p in teams[team].players]
    values = df[df["name"].isin(players_on_team)].groupby("position")["rollup"].mean().round().to_dict()
    values["team"] = team
    data.append(values)

# %%
pd.DataFrame(data).sort_values("F", ascending=False)
# Out:
#        D     F     G  team
# 0   38.0  49.0  48.0     1
# 1   38.0  48.0  49.0     2
# 2   42.0  48.0  53.0     3
# 10  43.0  48.0  64.0    11
# 11  43.0  48.0  63.0    12
# 9   39.0  47.0  56.0    10
# 4   39.0  46.0  59.0     5
# 5   37.0  46.0  61.0     6
# 7   38.0  46.0  63.0     8
# 8   39.0  46.0  52.0     9
# 3   39.0  45.0  60.0     4
# 6   40.0  45.0  63.0     7

# %%
teams[12].players
# Out:
# [Player("Roman Josi", "D", 29.0, 13.2),
#  Player("Victor Hedman", "D", 14.0, 12.5),
#  Player("Dougie Hamilton", "D", 46.5, 11.3),
#  Player("Philipp Grubauer", "G", 72.0, 8.2),
#  Player("Neal Pionk", "D", 80.5, 5.9),
#  Player("Anton Khudobin", "G", 74.0, 1.2),
#  Player("Jonathan Marchessault", "F", 97.0, -2.7),
#  Player("Mike Hoffman", "F", 86.0, -3.5),
#  Player("David Perron", "F", 124.0, -4.8),
#  Player("Patric Hornqvist", "F", 151.0, -5.0),
#  Player("Bryan Rust", "F", 178.0, -4.6),
#  Player("Chris Kreider", "F", 136.5, -5.9),
#  Player("Semyon Varlamov", "G", 163.0, -3.1),
#  Player("Alexander Edler", "D", 261.0, -3.8),
#  Player("Cam Talbot", "G", 217.0, -4.4),
#  Player("Erik Cernak", "D", 182.0, -6.7)]
