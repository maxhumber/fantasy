# %% [markdown]
# # Draft

# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 1_000

# %% [markdown]
# ### Pool Settings

# %%
# Bitcoin/Thugz League
TEAMS = 12
ROSTER = {'C': 2, 'LW': 2, 'RW': 2, 'D': 4, 'G': 2}

SKATER_CATEGORIES = {
    'goals': 5/8,          # focus for everyone else
    'assists': 1, 
    'plus_minus': 1/8,     # bad correlation
    'powerplay_points': 1, 
    'shots_on_goal': 1, 
    'hits': 1,
    'blocks': 1
}

GOALIE_CATEGORIES = {
    "wins" : 1,            # good team is good
    "save_percentage": 1/2, 
    "saves": 5/8, 
    "shutouts": 1/2        # can't predict
}

# %% [markdown]
# ### Players

# %%
pic = pd.read_csv("../data/adp-yahoo_com.csv")
cap = pd.read_csv("../data/info-capfriendly_com.csv")
players = pd.merge(pic, cap, how="left", on="name")

players["adp"] = players["pick"] 
players = players[['team', 'age', 'name', 'position', 'adp']]

players.head()
# Out:
#   team   age              name position  adp
# 0  Edm  23.0    Connor McDavid        C  1.6
# 1  Col  25.0  Nathan MacKinnon        C  2.5
# 2  Edm  25.0    Leon Draisaitl     C,LW  3.6
# 3  NYR  29.0    Artemi Panarin       LW  5.2
# 4  Was  35.0     Alex Ovechkin       LW  5.5

# %% [markdown]
# ### Multiple Positions

# %%
multi = (
    players
    [["name", "position"]]
    .set_index(['name']) 
    .apply(lambda col: col.str.split(',').explode())
    .reset_index()
)

multi.head()
# Out:
#                name position
# 0    Connor McDavid        C
# 1  Nathan MacKinnon        C
# 2    Leon Draisaitl        C
# 3    Leon Draisaitl       LW
# 4    Artemi Panarin       LW

# %% [markdown]
# ### Projection Data

# %%
proj = pd.read_csv("../data/projections-generated.csv")

# %% [markdown]
# ### Goalies

# %%
goalies = proj[proj["position"] == "G"].copy()

goalies = (
    goalies
    [["name"] + list(GOALIE_CATEGORIES.keys())]
    .set_index("name")
    .apply(lambda x: (x - x.min()) / (x.max() - x.min()))
)

for key, value in GOALIE_CATEGORIES.items():
    goalies[key] *= value
    
goalies["rollup"] = goalies.apply(lambda row: row.sum(), axis=1)
goalies["rollup"] /= sum(GOALIE_CATEGORIES.values())
goalies["rollup"] *= 100

goalies = goalies.reset_index()
goalies = goalies[["name", "rollup"]]

goalies.head()
# Out:
#                  name     rollup
# 0  Andrei Vasilevskiy  96.058195
# 1   Connor Hellebuyck  77.919895
# 2         Tuukka Rask  66.178592
# 3         Carter Hart  64.573863
# 4        Robin Lehner  69.378325

# %% [markdown]
# ### Skaters

# %%
skaters = proj[proj["position"] != "G"].copy()
skaters = (
    skaters
    [["name"] + list(SKATER_CATEGORIES.keys())]
    .set_index("name")
    .apply(lambda x: (x - x.min()) / (x.max() - x.min()))
)
     
for key, value in SKATER_CATEGORIES.items():
    skaters[key] *= value
    
skaters["rollup"] = skaters.apply(lambda row: row.sum(), axis=1)
skaters["rollup"] /= sum(SKATER_CATEGORIES.values())
skaters["rollup"] *= 100

skaters = skaters.reset_index()
skaters = skaters[["name", "rollup"]]

skaters.head()
# Out:
#                name     rollup
# 0    Connor McDavid  61.869332
# 1  Nathan MacKinnon  63.517697
# 2    Leon Draisaitl  58.949771
# 3    Artemi Panarin  48.720453
# 4     Alex Ovechkin  59.346880

# %% [markdown]
# ### Merge

# %%
rollup = pd.concat([skaters, goalies])
rollup = pd.merge(multi, rollup, how="inner", on="name").sort_values("rollup", ascending=False)
rollup.head()
# Out:
#                   name position     rollup
# 7   Andrei Vasilevskiy        G  96.058195
# 17   Connor Hellebuyck        G  77.919895
# 45   Jordan Binnington        G  72.210057
# 38        Robin Lehner        G  69.378325
# 61   Frederik Andersen        G  69.304398

# %% [markdown]
# ### VORP

# %%
vorp = rollup.copy()
vorp["vorp"] = vorp["rollup"]

for position, slots in ROSTER.items():
    replacement = (
        vorp[vorp['position'] == position]
        .sort_values('vorp', ascending=False)
        .head(slots * TEAMS)
        ['vorp']
        .mean()
    )
    vorp.loc[vorp['position'] == position, 'vorp'] = vorp['vorp'] - replacement

vorp.head()
# Out:
#                   name position     rollup       vorp
# 7   Andrei Vasilevskiy        G  96.058195  33.744156
# 17   Connor Hellebuyck        G  77.919895  15.605856
# 45   Jordan Binnington        G  72.210057   9.896018
# 38        Robin Lehner        G  69.378325   7.064285
# 61   Frederik Andersen        G  69.304398   6.990359

# %% [markdown]
# ### Draft

# %%
draft = pd.merge(players, vorp, how="left", on="name", suffixes=("_yahoo", ""))
draft = draft.dropna()
draft = draft.groupby("name").head(1).dropna()

draft = draft[[
    'team', 'age', 'name', 
    'position_yahoo', 'position',
    'rollup', 'vorp', 'adp',
]]

draft["rollup"] = draft["rollup"].round(1)
draft["vorp"] = draft["vorp"].round(1)

draft['pr_vorp'] = draft.groupby("position")['vorp'].rank(ascending=False)
draft['pr_adp'] = draft.groupby("position")['adp'].rank(ascending=True)

draft = draft.sort_values("adp", ascending=True)

# %%
draft["pr_arbitrage"] =  draft['pr_adp'] - draft['pr_vorp']
draft['round'] = draft["adp"] // TEAMS + 1

# %%
draft.sort_values("pr_arbitrage", ascending=False)
# Out:
#     team   age                   name position_yahoo position  rollup  vorp  \
# 323  Van  34.0        Alexander Edler              D        D    46.0   4.3
# 342  Edm  32.0         Mikko Koskinen              G        G    54.6  -7.8
# 166  Edm  25.0          Darnell Nurse              D        D    44.6   2.9
# 336   LA  36.0           Dustin Brown             RW       RW    36.1  -7.9
# 325  Ari  22.0         Jakob Chychrun              D        D    34.9  -6.8
# 312  VGK  33.0          Alec Martinez              D        D    36.6  -5.1
# 260  Min  33.0             Cam Talbot              G        G    55.5  -6.9
# 324  VGK  27.0       William Karlsson              C        C    34.7 -13.5
# 344  Anh  27.0         Rickard Rakell          LW,RW       LW    36.6  -9.7
# 164   LA  31.0           Drew Doughty              D        D    43.3   1.6
# 338  Ott  26.0            Matt Murray              G        G    43.5 -18.8
# 340  Cls  33.0           Nick Foligno          LW,RW       RW    34.8  -9.2
# 168  NYR  26.0           Jacob Trouba              D        D    42.7   1.1
# 236  Ari  33.0            Phil Kessel             RW       RW    38.0  -6.0
# 305  Cls  25.0     Oliver Bjorkstrand          LW,RW       LW    36.7  -9.5
# 294   SJ  30.0           Martin Jones              G        G    42.1 -20.2
# 150  Buf  26.0     Rasmus Ristolainen              D        D    43.0   1.4
# 320  Mon  27.0        Phillip Danault              C        C    32.4 -15.8
# 308  Car  27.0       Vincent Trocheck              C        C    33.9 -14.4
# 303  NYI  29.0           Brock Nelson              C        C    34.3 -14.0
# 330  StL  28.0           Justin Faulk              D        D    30.7 -11.0
# 287  NYI  28.0    Jean-Gabriel Pageau              C        C    35.4 -12.8
# 142  NYI  26.0            Ryan Pulock              D        D    43.7   2.0
# 354   SJ  34.0           Devan Dubnyk              G        G    23.8 -38.5
# 351   SJ  25.0           Kevin Labanc          LW,RW       RW    32.4 -11.6
# 213  Pit  28.0             Bryan Rust          LW,RW       LW    39.9  -6.3
# 327  Tor  28.0             Zach Hyman           C,LW       LW    32.4 -13.8
# 296  Dal  26.0            Esa Lindell              D        D    34.1  -7.5
# 167   LA  33.0           Anze Kopitar              C        C    41.3  -6.9
# 302  Phi  28.0        Erik Gustafsson              D        D    33.0  -8.6
# 175  Van  25.0              Bo Horvat              C        C    39.2  -9.0
# 154  Fla  32.0       Sergei Bobrovsky              G        G    61.0  -1.3
# 177  Col  25.0            Ryan Graves              D        D    40.4  -1.3
# 218  Min  31.0         Jared Spurgeon              D        D    38.0  -3.7
# 135  Dal  31.0             Jamie Benn           C,LW        C    41.8  -6.4
# 258  Min  36.0            Zach Parise             LW       LW    36.2 -10.0
# 309  Nsh  30.0         Mattias Ekholm              D        D    32.7  -9.0
# 210   TB  29.0           Ondrej Palat             LW       LW    37.8  -8.4
# 125  Mon  33.0             Jeff Petry              D        D    43.9   2.3
# 82   Edm  27.0    Ryan Nugent-Hopkins           C,LW        C    43.6  -4.6
# 138  Cgy  37.0          Mark Giordano              D        D    43.0   1.3
# 137  Nsh  25.0            Juuse Saros              G        G    62.2  -0.1
# 326  Buf  28.0           Jeff Skinner             LW       LW    32.2 -14.0
# 290  Pit  29.0          Casey DeSmith              G        G    28.3 -34.0
# 297  Bos  27.0          Matt Grzelcyk              D        D    32.9  -8.8
# 300  Cgy  31.0        Mikael Backlund           C,RW        C    31.4 -16.8
# 349   NJ  28.0           Nikita Gusev          LW,RW       LW    30.7 -15.5
# 93   Wpg  25.0             Neal Pionk              D        D    47.8   6.1
# 105  Was  26.0             Tom Wilson             RW       RW    41.6  -2.4
# 270  Chi  37.0           Duncan Keith              D        D    35.1  -6.6
# 269  Mon  26.0          Josh Anderson             RW       RW    33.9 -10.1
# 186  Mon  30.0            Tomas Tatar          LW,RW       RW    36.9  -7.1
# 348  NYR  24.0     Alexandar Georgiev              G        G    18.6 -43.8
# 318  Col  26.0            Devon Toews              D        D    27.5 -14.2
# 339   NJ  36.0         Corey Crawford              G        G    23.5 -38.8
# 295  NYR  25.0       Pavel Buchnevich             RW       RW    32.8 -11.2
# 319  StL  24.0             Vince Dunn              D        D    27.2 -14.4
# 224  Dal  36.0           Joe Pavelski           C,RW       RW    35.6  -8.4
# 44   VGK  32.0         Max Pacioretty             LW       LW    49.5   3.3
# 145  StL  32.0           David Perron          LW,RW       LW    40.4  -5.8
# 165  StL  27.0         Colton Parayko              D        D    40.5  -1.2
# 171  Min  35.0             Ryan Suter              D        D    38.4  -3.3
# 42   Wpg  34.0          Blake Wheeler           C,RW        C    50.2   2.0
# 293  Car  32.0           James Reimer              G        G    24.9 -37.4
# 85   Dal  34.0         Anton Khudobin              G        G    68.9   6.5
# 86   Col  29.0       Philipp Grubauer              G        G    68.4   6.0
# 332  Ari  22.0         Clayton Keller          LW,RW       RW    31.4 -12.6
# 161  NYR  29.0          Chris Kreider             LW       LW    40.0  -6.3
# 19   NYR  27.0         Mika Zibanejad              C        C    55.0   6.8
# 198  Tor  31.0            Jake Muzzin              D        D    36.8  -4.9
# 271  Pit  28.0           Jason Zucker          LW,RW       RW    32.5 -11.5
# 88    SJ  29.0           Evander Kane             LW       LW    43.1  -3.2
# 124  NYI  30.0             Anders Lee             LW       LW    40.3  -5.9
# 113  VGK  30.0  Jonathan Marchessault           C,LW       LW    42.1  -4.2
# 89   StL  29.0         Brayden Schenn           C,RW        C    41.3  -6.9
# 103   SJ  24.0             Timo Meier          LW,RW       RW    39.9  -4.1
# 194  NYI  32.0        Semyon Varlamov              G        G    50.3 -12.0
# 129   NJ  29.0          Kyle Palmieri             RW       RW    39.0  -5.0
# 31   Pit  34.0          Evgeni Malkin              C        C    51.2   3.0
# 215   LA  34.0         Jonathan Quick              G        G    44.3 -18.1
# 313  Mon  25.0        Jonathan Drouin           C,LW        C    30.5 -17.7
# 182   TB  29.0          Blake Coleman          LW,RW       RW    36.4  -7.6
# 281  Phi  28.0            Kevin Hayes              C        C    31.5 -16.7
# 62   Tor  31.0      Frederik Andersen              G        G    69.3   7.0
# 329  Buf  36.0             Eric Staal              C        C    28.5 -19.7
# 24    TB  30.0         Steven Stamkos          LW,RW       LW    51.0   4.8
# 50   Bos  35.0       Patrice Bergeron              C        C    45.6  -2.6
# 46   StL  27.0      Jordan Binnington              G        G    72.2   9.9
# 45   VGK  28.0             Mark Stone             RW       RW    47.1   3.1
# 40   Col  28.0      Gabriel Landeskog           C,LW        C    47.4  -0.8
# 173  Cgy  26.0           Sean Monahan              C        C    37.7 -10.5
# 244  Buf  27.0          Linus Ullmark              G        G    39.1 -23.3
# 139  Dal  34.0      Alexander Radulov          LW,RW       RW    38.4  -5.6
# 230  Phi  31.0          Jakub Voracek             RW       RW    34.8  -9.2
# 98   Phi  23.0         Travis Konecny             RW       RW    39.9  -4.1
# 298  Mon  28.0          Tyler Toffoli          LW,RW       RW    31.4 -12.6
# 57   Cgy  27.0        Johnny Gaudreau          LW,RW       RW    42.4  -1.6
# 334  Wpg  35.0           Paul Stastny              C        C    27.6 -20.7
# 33   Nsh  30.0             Roman Josi              D        D    54.3  12.6
# 1    Col  25.0       Nathan MacKinnon              C        C    63.5  15.3
# 143  Nsh  30.0             Ryan Ellis              D        D    41.7   0.0
# 5    Was  35.0          Alex Ovechkin             LW       LW    59.3  13.1
# 63   Buf  29.0            Taylor Hall             LW       LW    44.5  -1.7
# 64    SJ  35.0            Brent Burns              D        D    49.8   8.1
# 22   Was  30.0           John Carlson              D        D    55.7  14.0
# 76   Cgy  26.0         Elias Lindholm           C,RW       RW    42.3  -1.7
# 78   Pit  33.0            Kris Letang              D        D    47.4   5.8
# 13   Col  24.0         Mikko Rantanen             RW       RW    51.0   7.0
# 346  Dal  23.0         Denis Gurianov          LW,RW       RW    28.3 -15.7
# 289   TB  23.0        Anthony Cirelli              C        C    31.3 -16.9
# 148  Cls  26.0       Joonas Korpisalo              G        G    52.5  -9.8
# 34   Cgy  23.0        Matthew Tkachuk          LW,RW       LW    46.3   0.1
# 18   Wpg  27.0      Connor Hellebuyck              G        G    77.9  15.6
# 26   Pit  26.0          Jake Guentzel          LW,RW       RW    45.6   1.6
# 32   Tor  30.0           John Tavares              C        C    47.3  -0.9
# 12   Pit  33.0          Sidney Crosby              C        C    52.7   4.5
# 7     TB  26.0     Andrei Vasilevskiy              G        G    96.1  33.7
# 6    Tor  23.0        Auston Matthews              C        C    55.2   7.0
# 47   Fla  25.0      Aleksander Barkov              C        C    44.1  -4.1
# 172  Col  30.0            Nazem Kadri              C        C    37.4 -10.8
# 39   VGK  29.0           Robin Lehner              G        G    69.4   7.1
# 65   VGK  30.0       Alex Pietrangelo              D        D    47.7   6.0
# 256  Det  25.0         Tyler Bertuzzi          LW,RW       LW    31.9 -14.3
# 316  NYI  31.0            Josh Bailey          LW,RW       LW    29.7 -16.5
# 81   StL  29.0             Torey Krug              D        D    46.1   4.4
# 307  NYI  25.0           Ilya Sorokin              G        G    18.2 -44.1
# 2    Edm  25.0         Leon Draisaitl           C,LW        C    58.9  10.7
# 291  Chi  23.0           Dylan Strome           C,RW        C    30.9 -17.3
# 273  Dal  24.0            Roope Hintz           C,LW       LW    31.0 -15.2
# 132  Ott  23.0          Thomas Chabot              D        D    42.1   0.4
# 193  Anh  27.0            John Gibson              G        G    50.3 -12.1
# 284  Col  22.0          Samuel Girard              D        D    31.7 -10.0
# 151  Det  24.0           Dylan Larkin              C        C    38.3  -9.9
# 200  Cls  31.0           Cam Atkinson             RW       RW    34.9  -9.1
# 0    Edm  23.0         Connor McDavid              C        C    61.9  13.7
# 8    Buf  24.0            Jack Eichel              C        C    53.1   4.9
# 10   Chi  32.0           Patrick Kane             RW       RW    49.7   5.7
# 23   Bos  32.0          Brad Marchand             LW       LW    49.3   3.0
# 72   Phi  32.0          Claude Giroux           C,LW        C    40.2  -8.0
# 56   Wpg  27.0         Mark Scheifele              C        C    41.8  -6.4
# 28   Fla  27.0     Jonathan Huberdeau             LW       LW    45.0  -1.2
# 208  Det  26.0         Anthony Mantha          LW,RW       LW    35.3 -11.0
# 14    TB  30.0          Victor Hedman              D        D    51.6   9.9
# 20   Tor  23.0        Mitchell Marner             RW       RW    45.2   1.2
# 254  VGK  24.0              Alex Tuch          LW,RW       RW    31.6 -12.4
# 185  StL  28.0         Jaden Schwartz             LW       LW    36.6  -9.7
# 110  Cls  22.0      Pierre-Luc Dubois              C        C    39.0  -9.2
# 112  Phi  23.0          Ivan Provorov              D        D    42.8   1.1
# 197   NJ  22.0          Nico Hischier              C        C    32.4 -15.8
# 133   SJ  31.0          Logan Couture              C        C    38.3  -9.9
# 115  Chi  23.0         Alex DeBrincat          LW,RW       RW    36.8  -7.2
# 304  Nsh  31.0        Mark Borowiecki              D        D    23.4 -18.3
# 80   Mon  28.0      Brendan Gallagher             RW       RW    39.3  -4.7
# 79   Nsh  26.0         Filip Forsberg             LW       LW    40.0  -6.2
# 69   Phi  28.0         Sean Couturier              C        C    39.9  -8.3
# 276  Ari  31.0           Antti Raanta              G        G    21.1 -41.2
# 180  VGK  29.0           Reilly Smith             RW       RW    35.0  -9.0
# 4    NYR  29.0         Artemi Panarin             LW       LW    48.7   2.5
# 118  Min  24.0            Kevin Fiala          LW,RW       LW    37.2  -9.0
# 162  NYR  27.0            Ryan Strome           C,RW        C    36.8 -11.4
# 29   Wpg  22.0           Patrik Laine          LW,RW       LW    42.7  -3.5
# 219  Nsh  38.0            Pekka Rinne              G        G    26.5 -35.8
# 321  Pit  29.0          Brandon Tanev          LW,RW       RW    27.0 -17.0
# 55   Car  27.0        Dougie Hamilton              D        D    47.3   5.7
# 315  Chi  25.0         Nikita Zadorov              D        D    20.8 -20.9
# 74   Ari  30.0          Darcy Kuemper              G        G    54.9  -7.4
# 149   TB  22.0      Mikhail Sergachev              D        D    38.3  -3.4
# 121  Van  31.0          Braden Holtby              G        G    50.3 -12.0
# 54   Bos  24.0         David Pastrnak             RW       RW    39.5  -4.5
# 60   Mon  33.0            Carey Price              G        G    56.8  -5.5
# 278  Buf  35.0          Carter Hutton              G        G    17.0 -45.3
# 36   Bos  33.0            Tuukka Rask              G        G    66.2   3.9
# 169   SJ  27.0            Tomas Hertl           C,LW        C    34.3 -13.9
# 190  Car  26.0          Jaccob Slavin              D        D    33.6  -8.1
# 206  Cls  25.0               Max Domi           C,LW        C    31.3 -16.9
# 201  Wpg  24.0         Nikolaj Ehlers          LW,RW       LW    32.3 -13.9
# 259  Bos  34.0           David Krejci              C        C    30.8 -17.4
# 11   Car  23.0          Sebastian Aho              C        C    46.5  -1.7
# 66   StL  29.0          Ryan O'Reilly              C        C    39.5  -8.7
# 205  Anh  31.0      Kevin Shattenkirk              D        D    32.8  -8.9
# 21    TB  24.0          Brayden Point              C        C    43.1  -5.1
# 75   Wpg  24.0            Kyle Connor             LW       LW    39.7  -6.5
# 245   TB  31.0           Alex Killorn          LW,RW       LW    29.5 -16.7
# 203  Van  25.0         Thatcher Demko              G        G    25.7 -36.6
# 261  Fla  25.0        Anthony Duclair          LW,RW       RW    28.5 -15.5
# 277  Nsh  28.0          Ryan Johansen              C        C    30.1 -18.1
# 70   Pit  25.0          Tristan Jarry              G        G    52.7  -9.6
# 97   Cls  26.0             Seth Jones              D        D    42.6   0.9
# 263   TB  31.0          Ryan McDonagh              D        D    30.4 -11.2
# 159  Buf  25.0        Victor Olofsson          LW,RW       LW    34.3 -11.9
# 247  Pit  24.0        Kasperi Kapanen          LW,RW       LW    26.9 -19.3
# 188  Nsh  29.0           Matt Duchene           C,RW        C    31.3 -16.9
# 95   Tor  24.0       William Nylander          LW,RW       LW    36.5  -9.7
# 128  Cls  26.0       Elvis Merzlikins              G        G    40.7 -21.6
# 147  Fla  34.0           Keith Yandle              D        D    36.9  -4.8
# 152  Chi  25.0        Dominik Kubalik          LW,RW       RW    34.3  -9.7
# 234  Bos  24.0           Jake DeBrusk          LW,RW       RW    29.4 -14.6
# 108  VGK  25.0          Shea Theodore              D        D    41.6  -0.0
# 228  Phi  31.0     James van Riemsdyk             LW       LW    27.3 -18.9
# 288  Mon  29.0            Ben Chiarot              D        D    22.0 -19.7
# 156  Buf  25.0           Sam Reinhart           C,RW       RW    33.0 -11.0
# 68   Was  28.0       Evgeny Kuznetsov              C        C    37.8 -10.4
# 242  Bos  28.0          Charlie Coyle           C,RW        C    29.4 -18.8
# 275  Phi  24.0         Travis Sanheim              D        D    26.3 -15.4
# 195  Nsh  27.0       Viktor Arvidsson          LW,RW       LW    31.1 -15.1
# 222  Bos  31.0            Craig Smith             RW       RW    30.6 -13.4
# 87   Van  23.0           Brock Boeser             RW       RW    35.2  -8.8
# 237  Col  28.0           Brandon Saad          LW,RW       LW    26.2 -20.0
# 120  Edm  29.0           Tyson Barrie              D        D    39.2  -2.5
# 155  Fla  24.0           Aaron Ekblad              D        D    35.0  -6.7
# 282  Was  29.0           Dmitry Orlov              D        D    22.9 -18.8
# 99    SJ  30.0          Erik Karlsson              D        D    41.7  -0.0
# 109  Mon  35.0             Shea Weber              D        D    41.0  -0.7
# 126  Bos  23.0         Charlie McAvoy              D        D    38.2  -3.4
# 251  Tor  28.0          Jack Campbell              G        G    13.1 -49.2
# 184  Van  29.0           Nate Schmidt              D        D    31.0 -10.7
# 111  Col  30.0         Pavel Francouz              G        G    39.1 -23.2
# 233  Mon  30.0             Jake Allen              G        G    14.0 -48.3
# 216  Dal  28.0           Tyler Seguin           C,RW        C    27.8 -20.4
# 211  StL  29.0     Vladimir Tarasenko             RW       RW    29.9 -14.1
# 223  Det  34.0          Thomas Greiss              G        G    16.5 -45.9
# 67   Tor  26.0          Morgan Rielly              D        D    42.2   0.6
# 232  VGK  33.0            Ryan Reaves             RW       RW    25.3 -18.7
# 286  Bos  24.0          Brandon Carlo              D        D    19.8 -21.8
# 229  Cgy  28.0          David Rittich              G        G    13.1 -49.2
# 141  Dal  34.0             Ben Bishop              G        G    23.6 -38.7
# 130  Ari  29.0   Oliver Ekman-Larsson              D        D    36.7  -5.0
# 221   TB  23.0            Erik Cernak              D        D    22.5 -19.2
# 117  Dal  28.0         John Klingberg              D        D    37.6  -4.1
# 174  Min  26.0             Matt Dumba              D        D    26.4 -15.3
# 176  Chi  32.0         Jonathan Toews              C        C    21.2 -27.0
#
#        adp  pr_vorp  pr_adp  pr_arbitrage  round
# 323  173.6     10.0    58.0          48.0   15.0
# 342  176.8     14.0    38.0          24.0   15.0
# 166  136.0     11.0    31.0          20.0   12.0
# 128  112.6     23.0    14.0          -9.0   10.0
# 147  125.3     34.0    25.0          -9.0   11.0
# 152  129.7     26.0    17.0          -9.0   11.0
# 234  164.1     37.0    27.5          -9.5   14.0
# 108   92.6     23.0    13.0         -10.0    8.0
# 228  163.4     36.0    26.0         -10.0   14.0
# 288  170.1     58.0    48.0         -10.0   15.0
# 156  130.9     28.0    18.0         -10.0   11.0
# 68    64.3     28.0    18.0         -10.0    6.0
# 242  164.5     48.0    38.0         -10.0   14.0
# 275  168.8     54.0    44.0         -10.0   15.0
# 195  157.3     31.0    21.0         -10.0   14.0
# 222  162.7     35.0    24.0         -11.0   14.0
# 87    76.7     21.0    10.0         -11.0    7.0
# 237  164.3     38.0    27.0         -11.0   14.0
# 120  103.2     28.0    17.0         -11.0    9.0
# 155  130.8     39.0    28.0         -11.0   11.0
# 282  169.6     56.0    45.0         -11.0   15.0
# 99    85.3     23.0    12.0         -11.0    8.0
# 109   93.0     25.0    14.0         -11.0    8.0
# 126  112.1     30.5    19.0         -11.5   10.0
# 251  165.8     39.5    28.0         -11.5   14.0
# 184  151.9     48.0    36.0         -12.0   13.0
# 111   97.7     24.0    12.0         -12.0    9.0
# 233  164.1     38.0    26.0         -12.0   14.0
# 216  161.8     50.0    37.0         -13.0   14.0
# 211  160.8     36.0    23.0         -13.0   14.0
# 223  163.0     37.0    24.0         -13.0   14.0
# 67    64.2     20.0     7.0         -13.0    6.0
# 232  164.1     41.0    27.5         -13.5   14.0
# 286  169.8     60.0    46.5         -13.5   15.0
# 229  163.5     39.5    25.0         -14.5   14.0
# 141  121.8     31.0    16.0         -15.0   11.0
# 130  115.4     36.0    20.0         -16.0   10.0
# 221  162.6     57.0    41.0         -16.0   14.0
# 117  101.9     33.0    16.0         -17.0    9.0
# 174  144.4     53.0    34.0         -19.0   13.0
# 176  148.7     52.0    33.0         -19.0   13.0

# %%
pd.DataFrame(draft.groupby(["round"])['position'].value_counts())
# Out:
#                 position
# round position
# 1.0   C                6
#       LW               2
#       G                1
#       RW               1
# 2.0   C                3
#       D                2
#       LW               2
#       RW               2
#       G                1
# 3.0   LW               3
#       C                2
#       G                2
#       D                1
#       RW               1
# 4.0   C                5
#       RW               3
#       D                1
#       G                1
#       LW               1
# 5.0   D                2
#       G                2
#       LW               1
# 6.0   C                4
#       D                3
#       G                2
#       LW               2
#       RW               2
# 7.0   C                2
#       G                2
#       LW               2
#       D                1
#       RW               1
# 8.0   D                4
#       RW               3
#       C                1
# 9.0   D                3
#       LW               3
#       G                2
#       RW               1
# 10.0  D                5
#       C                2
#       G                2
#       RW               1
# 11.0  D                6
#       G                3
#       RW               3
#       LW               2
#       C                1
# 12.0  C                5
#       D                5
#       LW               1
# 13.0  D                4
#       C                3
#       RW               3
#       LW               1
# 14.0  G               11
#       LW              11
#       RW              10
#       C                5
#       D                5
# 15.0  D               18
#       C               13
#       G                9
#       RW               9
#       LW               6
# 16.0  G                2
#       LW               1
#       RW               1

# %% [markdown]
# ### Export

# %%
draft.to_csv("../data/draft-thugz_league.csv", index=False)
